# %% [markdown]
# #***A02 - Data Manipulation for Modeling***
#     **Arturo Ayala Hernández**
# **Datos utilizados**: Boston Housing Dataset 1978.xlsx

# %% [markdown]
# IMPORTAMOS LOS DATOS

# %%
import numpy as np
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt
from google.colab import files
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[9], line 4
#       2 from sklearn.linear_model import LinearRegression
#       3 import matplotlib.pyplot as plt
# ----> 4 from google.colab import files
#       5 import pandas as pd
#
# ModuleNotFoundError: No module named 'google'

# %%
files = files.upload()

# %%
FILE = 'Boston Housing Dataset 1978 (1).xlsx'
raw_df = pd.read_excel(FILE)

# %% [markdown]
# ANALIZAMOS LOS DATOS EDA

# %%
raw_df.describe()

# %%
raw_df.info()

# %%
raw_df.head()

# %% [markdown]
# CONSEGUIMOS EL RANGO (POR CADA ELEMENTO)

# %%
rango = raw_df.max() - raw_df.min()
rango[:]

# %% [markdown]
# ESCALAMOS (0-1)...

# %%
min_values = raw_df.min()
max_values = raw_df.max()

#cADA ELEMENTO DE LA DF LE RESTAMOS EL VALOR MINIMO Y DIVIDIMOS SU RANGO
normal_df = (raw_df - min_values) / (rango)


#COMPROBAMOS
print(normal_df.head())

# %%
print(normal_df.describe())

# %% [markdown]
# ESCALAMIENTO ESTANDAR (Z)

# %%
#cADA ELEMENTO DE LA DF LE RESTAMOS EL VALOR MINIMO Y DIVIDIMOS SU RANGO
normal_df = (raw_df - raw_df.mean()) / (raw_df.std())


#COMPROBAMOS
print(normal_df.head())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 2
#       1 #cADA ELEMENTO DE LA DF LE RESTAMOS EL VALOR MINIMO Y DIVIDIMOS SU RANGO
# ----> 2 normal_df = (raw_df - raw_df.mean()) / (raw_df.std())
#       5 #COMPROBAMOS
#       6 print(normal_df.head())
#
# NameError: name 'raw_df' is not defined

# %%
normal_df.describe()

# %% [markdown]
# ESCALAMIENTO ESTANDAR

# %%
import matplotlib.pyplot as plt


plt.hist(normal_df)

plt.xlabel("X")
plt.ylabel("Y")
plt.title("Datos escalados")

plt.show()
